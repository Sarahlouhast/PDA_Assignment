# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
rng = np.random.default_rng()
x = rng.random(100000)

# %%
print(x)
# Out:
# [0.5984017  0.45125216 0.07271104 ... 0.08903079 0.68582893 0.31136699]

# %%
plt.hist(x)
plt.show()
